# %% [markdown]
# # Importing Libraries & Datasets

# %%
# import libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import statistics as stat
import seaborn as sns

# %%
insilico_favorable = pd.read_csv("Go insilico favorable.csv")
insilico_unfavorable = pd.read_csv("Go insilico unfavorable.csv")
clinical_favorable = pd.read_csv("Go clinical favorable.csv")
clinical_unfavorable = pd.read_csv("Go clinical unfavorable.csv")
zebrafish_favorable = pd.read_csv("Go zebrafish favorable.csv")
zebrafish_unfavorable = pd.read_csv("Go zebrafish unfavorable.csv")

# %% [markdown]
# # All Dataset Analysis

# %%
# Extract unique terms from each DataFrame
terms_sets = []
for df in [insilico_favorable, insilico_unfavorable, clinical_favorable, clinical_unfavorable, zebrafish_favorable, zebrafish_unfavorable]:
    terms_sets.append(set(df['Term']))

# Find the common terms
common_terms = set.intersection(*terms_sets)

print("Common terms among all datasets:")
for term in common_terms:
    print(term)
# Out:
# Common terms among all datasets:
# Adenyl Ribonucleotide Binding (GO:0032559)
# Heme Binding (GO:0020037)
# Protein Kinase Binding (GO:0019901)

# %% [markdown]
# # Favorable Terms

# %%
# Step 1: Set 'Term' as the index and select the relevant columns
insilico_data = insilico_favorable.set_index('Term')[['Adjusted P-value', 'Genes']]
invivo_data = zebrafish_favorable.set_index('Term')[['Adjusted P-value', 'Genes']]
clinical_data = clinical_favorable.set_index('Term')[['Adjusted P-value', 'Genes']]

# Step 2: Find common GO enrichment terms
common_terms = set(insilico_data.index).intersection(invivo_data.index, clinical_data.index)

# Step 3: Filter DataFrames to include only common terms
insilico_common = insilico_data.loc[common_terms]
invivo_common = invivo_data.loc[common_terms]
clinical_common = clinical_data.loc[common_terms]

# Step 4: Merge the DataFrames on the common terms
merged_df = pd.concat([
    insilico_common.add_suffix('_insilico'),
    invivo_common.add_suffix('_invivo'),
    clinical_common.add_suffix('_clinical')
], axis=1)

# Step 5: Reset the index for readability
merged_df.reset_index(inplace=True)

# Display the resulting DataFrame
merged_df = pd.DataFrame(merged_df)
merged_df
# Out:
#                                                  Term  \
# 0     G Protein-Coupled Receptor Binding (GO:0001664)
# 1   RNA Polymerase II Transcription Regulatory Reg...
# 2   Monoamine Transmembrane Transporter Activity (...
# 3                    Epinephrine Binding (GO:0051379)
# 4       Ubiquitin Protein Ligase Binding (GO:0031625)
# 5   Ribonucleoside Triphosphate Phosphatase Activi...
# 6                           Heme Binding (GO:0020037)
# 7   Ubiquitin-Like Protein Ligase Binding (GO:0044...
# 8   Voltage-Gated Calcium Channel Activity (GO:000...
# 9          Adenyl Ribonucleotide Binding (GO:0032559)
# 10           Monocarboxylic Acid Binding (GO:0033293)
# 11                       GTPase Activity (GO:0003924)
# 12                Protein Kinase Binding (GO:0019901)
# 13         Sequence-Specific DNA Binding (GO:0043565)
# 14  Guanyl-Nucleotide Exchange Factor Activity (GO...
# 15             GTPase Regulator Activity (GO:0030695)
# 16  Purine Ribonucleoside Triphosphate Binding (GO...
# 17           Double-Stranded DNA Binding (GO:0003690)
# 18                        Kinase Binding (GO:0019900)
# 19  Voltage-Gated Monoatomic Cation Channel Activi...
# 20                           ATP Binding (GO:0005524)
# 21              Alkali Metal Ion Binding (GO:0031420)
# 22          Steroid Hydroxylase Activity (GO:0008395)
# 23     Protein Homodimerization Activity (GO:0042803)
# 24  Sequence-Specific Double-Stranded DNA Binding ...
# 25                        ATPase Binding (GO:0051117)
#
#     Adjusted P-value_insilico                  Genes_insilico  \
# 0                    0.005006     GNAZ;GNA14;GNA15;GNA11;GNAQ
# 1                    0.773192            MGAM;THRA;NR1D1;ESR1
# 2                    0.000013  SLC22A3;SLC22A2;SLC18A2;SLC6A3
# 3                    0.078984                           ADRB3
# 4                    0.373503                     KCNH2;SCN5A
# 5                    0.028032     GNAZ;GNA14;GNA15;GNA11;GNAQ
# 6                    0.116201                   CYP11A1;NR1D1
# 7                    0.399727                     KCNH2;SCN5A
# 8                    0.242664                           SCN5A
# 9                    0.763761                          KCNJ11
# 10                   0.175486                         UGT2B15
# 11                   0.027999     GNAZ;GNA14;GNA15;GNA11;GNAQ
# 12                   0.693422                      SCN5A;ESR1
# 13                   0.803226                      NR1D1;ESR1
# 14                   0.634921                          P2RY12
# 15                   0.321041             P2RY12;GNAQ;ALDH1A1
# 16                   0.113348   GNA14;GNA15;KCNJ11;GNA11;GNAQ
# 17                   0.773192                      NR1D1;ESR1
# 18                   0.634921                      SCN5A;ESR1
# 19                   0.026257             KCNH2;KCNJ11;KCNMA1
# 20                   0.732862                          KCNJ11
# 21                   0.121724                          KCNJ11
# 22                   0.026257                  CYP11A1;CYP1A1
# 23                   0.596971                KCNH2;NQO2;ADRB3
# 24                   0.242257    KCNH2;THRA;CYP1A1;NR1D1;ESR1
# 25                   0.323802                            ESR1
#
#     Adjusted P-value_invivo           Genes_invivo  Adjusted P-value_clinical  \
# 0                  0.369307                   GNAZ                   0.001692
# 1                  0.640130    CYP27B1;ADRA2A;ESR2                   0.938217
# 2                  0.075349                SLC22A3                   0.001692
# 3                  0.004314          ADRA2C;ADRA2B                   0.000003
# 4                  0.212856            DERL1;SCN5A                   0.495980
# 5                  0.576798                   GNAZ                   0.062571
# 6                  0.071864        CYP27A1;CYP11B2                   0.000435
# 7                  0.233050            DERL1;SCN5A                   0.504858
# 8                  0.062216           SCN10A;SCN5A                   0.143191
# 9                  0.608155                 KCNJ11                   0.524432
# 10                 0.121941                 AKR1C3                   0.106389
# 11                 0.576798                   GNAZ                   0.061837
# 12                 0.448281           SCN5A;ADRA2A                   0.382072
# 13                 0.608155           ADRA2A;NR3C2                   0.806942
# 14                 0.480190                 TBXA2R                   0.422296
# 15                 0.685352                 TBXA2R                   0.304463
# 16                 0.718279                 KCNJ11                   0.350685
# 17                 0.576798           ADRA2A;NR3C2                   0.780619
# 18                 0.398751           SCN5A;ADRA2A                   0.338121
# 19                 0.237908                 KCNJ11                   0.210876
# 20                 0.585099                 KCNJ11                   0.501721
# 21                 0.083808                 KCNJ11                   0.072104
# 22                 0.019238        CYP27A1;CYP11B2                   0.000004
# 23                 0.140628  MME;FYN;ADRA2C;ADRA2A                   0.015143
# 24                 0.608155           ADRA2A;NR3C2                   0.504858
# 25                 0.233985                  DERL1                   0.208271
#
#                             Genes_clinical
# 0                     GNAO1;GNAZ;NPB;GNAT2
# 1                                   ADRA2A
# 2                            SLC6A2;SLC6A4
# 3                       ADRA2C;ADRA2B;DRD4
# 4                                    DERL1
# 5                         GNAO1;GNAZ;GNAT2
# 6             CYP2C9;CYP1A2;CYP2E1;CYP2C19
# 7                                    DERL1
# 8                                    OPRM1
# 9                                    ABCB1
# 10                                  UGT1A4
# 11                        GNAO1;GNAZ;GNAT2
# 12                              CRK;ADRA2A
# 13                                  ADRA2A
# 14                                  SLC6A2
# 15                           RANBP2;SLC6A2
# 16                             ABCB1;GNAT2
# 17                                  ADRA2A
# 18                              CRK;ADRA2A
# 19                                   OPRM1
# 20                                   ABCB1
# 21                                  SLC6A4
# 22            CYP2C9;CYP1A2;CYP1A1;CYP2C19
# 23  NTRK1;NTRK2;UGT1A4;ADRA2C;ADRA2A;ABCG2
# 24                           CYP1A1;ADRA2A
# 25                                   DERL1

# %%
# Save merged_df to a CSV file
merged_df.to_csv('common_favorable_go_enrichment_terms.csv', index=False)

# %%
# Filter merged_df to include only rows where at least one p-value is below 0.05
filtered_df = merged_df[
    (merged_df['Adjusted P-value_insilico'] < 0.05) |
    (merged_df['Adjusted P-value_invivo'] < 0.05) |
    (merged_df['Adjusted P-value_clinical'] < 0.05)
]

# Display the filtered DataFrame
filtered_df = pd.DataFrame(filtered_df)
filtered_df = filtered_df.reset_index(drop=True)
filtered_df.to_csv('common_significant_favorable_go_terms.csv', index=False)

# %%
# Filter terms with at least one P-value less than 0.05
significant_terms = []
for term in common_terms:
    if insilico_data.get(term, float('inf')) < 0.05 or \
       clinical_data.get(term, float('inf')) < 0.05 or \
       zebrafish_data.get(term, float('inf')) < 0.05:
        significant_terms.append(term)

num_significant_terms = len(significant_terms)
print(str(num_significant_terms) + " terms common to all datasets")

print("Terms common to all datasets with at least one P-value less than 0.05:")
for term in significant_terms:
    print("Term:", term)
    print("P-value (insilico):", insilico_data.get(term, "N/A"))
    print("P-value (clinical):", clinical_data.get(term, "N/A"))
    print("P-value (zebrafish):", zebrafish_data.get(term, "N/A"))
    print()  # Adding a blank line for readability
# Out:
# 9 terms common to all datasets
# Terms common to all datasets with at least one P-value less than 0.05:
# Term: G Protein-Coupled Receptor Binding (GO:0001664)
# P-value (insilico): 0.005005876121
# P-value (clinical): 0.00169249292
# P-value (zebrafish): 0.3693067083
#
# Term: Monoamine Transmembrane Transporter Activity (GO:0008504)
# P-value (insilico): 1.26e-05
# P-value (clinical): 0.00169249292
# P-value (zebrafish): 0.07534874112
#
# Term: Epinephrine Binding (GO:0051379)
# P-value (insilico): 0.07898414496
# P-value (clinical): 2.77e-06
# P-value (zebrafish): 0.00431381726
#
# Term: Ribonucleoside Triphosphate Phosphatase Activity (GO:0017111)
# P-value (insilico): 0.02803191577
# P-value (clinical): 0.06257115071
# P-value (zebrafish): 0.5767982091
#
# Term: Heme Binding (GO:0020037)
# P-value (insilico): 0.1162013799
# P-value (clinical): 0.000435
# P-value (zebrafish): 0.07186377216
#
# Term: GTPase Activity (GO:0003924)
# P-value (insilico): 0.02799863955
# P-value (clinical): 0.06183662888
# P-value (zebrafish): 0.5767982091
#
# Term: Voltage-Gated Monoatomic Cation Channel Activity (GO:0022843)
# P-value (insilico): 0.0262571527
# P-value (clinical): 0.210876112
# P-value (zebrafish): 0.2379078647
#
# Term: Steroid Hydroxylase Activity (GO:0008395)
# P-value (insilico): 0.0262571527
# P-value (clinical): 3.92e-06
# P-value (zebrafish): 0.01923833482
#
# Term: Protein Homodimerization Activity (GO:0042803)
# P-value (insilico): 0.5969714952
# P-value (clinical): 0.01514257978
# P-value (zebrafish): 0.140628164

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Extract unique terms from each DataFrame
insilico_terms = set(insilico_favorable['Term'])
clinical_terms = set(clinical_favorable['Term'])
zebrafish_terms = set(zebrafish_favorable['Term'])

# Create the Venn diagram
venn3(subsets=(len(insilico_terms - clinical_terms - zebrafish_terms),  # insilico only
               len(clinical_terms - insilico_terms - zebrafish_terms),  # clinical only
               len(insilico_terms & clinical_terms - zebrafish_terms),  # insilico and clinical
               len(zebrafish_terms - insilico_terms - clinical_terms),  # zebrafish only
               len(insilico_terms & zebrafish_terms - clinical_terms),  # insilico and zebrafish
               len(clinical_terms & zebrafish_terms - insilico_terms),  # clinical and zebrafish
               len(insilico_terms & clinical_terms & zebrafish_terms)),  # common to all
      set_labels=('Insilico', 'Clinical', 'Zebrafish'))

# Display the plot
plt.title("Venn Diagram of Common Favorable Terms")
plt.show()

# %% [markdown]
# # Unfavorable Terms

# %%
# Step 1: Set 'Term' as the index and select the relevant columns
insilico_data = insilico_unfavorable.set_index('Term')[['Adjusted P-value', 'Genes']]
invivo_data = zebrafish_unfavorable.set_index('Term')[['Adjusted P-value', 'Genes']]
clinical_data = clinical_unfavorable.set_index('Term')[['Adjusted P-value', 'Genes']]

# Step 2: Find common GO enrichment terms
common_terms = set(insilico_data.index).intersection(invivo_data.index, clinical_data.index)

# Step 3: Filter DataFrames to include only common terms
insilico_common = insilico_data.loc[common_terms]
invivo_common = invivo_data.loc[common_terms]
clinical_common = clinical_data.loc[common_terms]

# Step 4: Merge the DataFrames on the common terms
merged_df = pd.concat([
    insilico_common.add_suffix('_insilico'),
    invivo_common.add_suffix('_invivo'),
    clinical_common.add_suffix('_clinical')
], axis=1)

# Step 5: Reset the index for readability
merged_df.reset_index(inplace=True)

# Display the resulting DataFrame
merged_df = pd.DataFrame(merged_df)
# Save merged_df to a CSV file
merged_df.to_csv('common_unfavorable_go_enrichment_terms.csv', index=False)

# %%
# Filter merged_df to include only rows where at least one p-value is below 0.05
filtered_df = merged_df[
    (merged_df['Adjusted P-value_insilico'] < 0.05) |
    (merged_df['Adjusted P-value_invivo'] < 0.05) |
    (merged_df['Adjusted P-value_clinical'] < 0.05)
]

# Display the filtered DataFrame
filtered_df = pd.DataFrame(filtered_df)
filtered_df = filtered_df.reset_index(drop=True)
filtered_df.to_csv('common_significant_unfavorable_go_terms.csv', index=False)

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
# Extract unique terms from each DataFrame
insilico_terms_2 = set(insilico_unfavorable['Term'])
clinical_terms_2 = set(clinical_unfavorable['Term'])
zebrafish_terms_2 = set(zebrafish_unfavorable['Term'])

# Create the Venn diagram
venn3(subsets=(len(insilico_terms_2 - clinical_terms_2 - zebrafish_terms_2),  # insilico only
               len(clinical_terms_2 - insilico_terms_2 - zebrafish_terms_2),  # clinical only
               len(insilico_terms_2 & clinical_terms_2 - zebrafish_terms_2),  # insilico and clinical
               len(zebrafish_terms_2 - insilico_terms_2 - clinical_terms_2),  # zebrafish only
               len(insilico_terms_2 & zebrafish_terms_2 - clinical_terms_2),  # insilico and zebrafish
               len(clinical_terms_2 & zebrafish_terms_2 - insilico_terms_2),  # clinical and zebrafish
               len(insilico_terms_2 & clinical_terms_2 & zebrafish_terms_2)),  # common to all
      set_labels=('Insilico', 'Clinical', 'Zebrafish'))

# Display the plot
plt.title("Venn Diagram of Common Unfavorable Terms")
plt.show()
